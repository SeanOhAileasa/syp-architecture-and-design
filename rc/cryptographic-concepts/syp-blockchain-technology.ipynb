# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/syp-architecture-and-design/blob/main/README.md) >
#
# ## CompTIA Security+ - Course Material 2022
# ###### Topic: ``Blockchain Technology``
# ***

# %% [markdown]
# Course material for the ``CompTIA Security+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Blockchain Technology](#a) <br/><br/>
#
# - [Process](#b) <br/><br/>
#     - [Add Transaction](#b) <br/><br/>
#     - [Transaction Confirmed Verified](#c) <br/><br/>
#         - [Send to all Participants](#c) <br/><br/>
#     - [Add to other Blocks of Verified Transactions ](#d) <br/><br/>
#     - [Integrity](#e) <br/><br/>
#         - [Hash](#e) <br/><br/>
#     - [Add to Existing Blockchain](#f) <br/><br/>
# - [Distributed Ledger Concerns](#g)
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="a"></a>
# ***
# ### Blockchain Technology
# ***

# %% [markdown]
# A ``Blockchain`` is a distributed ledger - a way to keep track of a particular event.
#
# This is something that many people can participate in, so that this ledger can be distributed throughout many different devices and because this ledger is distributed across multiple devices, we can now have checks and balances - can have an efficient form of processing these transactions, and everyone can see exactly what’s happening on the blockchain.
#
# If you’ve ever purchased anything with cryptocurrency, then you’ve used blockchain technology for your payment processing - this can also be done for digital identification - can keep track of components as they move along different sections of a supply chain, or we could use this for secure voting.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="b"></a>
# ***
# ###### Process - Add Transaction
# ***

# %% [markdown]
# Regardless of the underlying application, the fundamentals of the blockchain are the same across all of these.
#
# The first step is adding a transaction - might be voting online - might be adding inventory into a supply chain process, or we may be purchasing something with cryptocurrency.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="c"></a>
# ***
# ###### Process - Transaction Confirmed Verified - Send to all Participants
# ***

# %% [markdown]
# Before the transaction is confirmed and verified, a copy of the transaction is sent to all of the devices that are participating as part of this blockchain.
#
# All of these devices are maintaining ledgers, and they can check balances and other information that’s important for completing this individual transaction.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="d"></a>
# ***
# ###### Process - Add to other Blocks of Verified Transactions
# ***

# %% [markdown]
# Once this transaction is verified, it’s added into a block of other transactions that have also been verified - this is the block of the blockchain, and it allows us to process many transactions at the same time.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="e"></a>
# ***
# ###### Process - Integrity - Hashing Function
# ***

# %% [markdown]
# To provide some integrity to the process, we’ll use a hashing function to be able to hash all of these transactions, and we will add the hash to the block - that way if anything changes with this block, we know that the block was modified, and therefore, the block would be invalid.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="f"></a>
# ***
# ###### Process - Created Hash - Add to Existing Blockchain
# ***

# %% [markdown]
# Once that hash is created we have a complete block that we can then add to the existing blockchain, so this block is now copied to all of the devices maintaining that ledger across the entire blockchain network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="g"></a>
# ***
# ###### Distributed Ledger Concerns
# ***

# %% [markdown]
# One of the concerns with having a distributed ledger is that any of these nodes on the network might want to make changes to something that has already been verified.
#
# That’s why the hash was added to each one of these blocks, so that if any changes are made we’ll know immediately that this information has been modified and since we’re able to verify the hashes that are part of every block, we will know immediately if any changes have been made to any of this verified information and we can discard anything that doesn’t match or verify with that existing hash.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is a broad overview of the blockchain process, but every blockchain technology has different minor nuances that make it unique from others and there may be different features or different capabilities based on the type of blockchain that you’re using.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# J. "Professor" Messer, "CompTIA Security+ (SY0-601) Course Notes," [professormesser.com](https://web.archive.org/web/20220521181010/https://www.professormesser.com/security-plus/sy0-601/sy0-601-video/sy0-601-comptia-security-plus-course/), September 2021.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# C:\Users\SeanOhAileasa\AppData\Local\Temp\ipykernel_12508\1322614208.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display,HTML
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
